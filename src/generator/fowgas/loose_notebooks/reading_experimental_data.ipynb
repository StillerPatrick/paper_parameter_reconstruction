# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# %cd /home/mz6084/fowgas/data/hibef/beamtimes/LCLS/1610_lcls_mec_ln04/evaluation/gratings_Jena/gratings_Jena/
#%ls
# Out:
# /home/mz6084/fowgas/data/hibef/beamtimes/LCLS/1610_lcls_mec_ln04/evaluation/gratings_Jena/gratings_Jena

# %%
path = 'run_139_frame_1_preshot_300nm_-2000fs.tif'

fig = plt.figure(figsize=(20, 12))

im = np.array(Image.open(path))
#plt.imshow(im[:,851:883], aspect=0.03)
plt.imshow(im[:,:])

# %%
path = 'run_139_frame_1_preshot_300nm_-2000fs_mask.tif'

fig = plt.figure(figsize=(20, 12))

im = np.array(Image.open(path))
#plt.imshow(im[:,851:883], aspect=0.03)
plt.imshow(im[:,:])

# %%
#print(np.histogram(im))

def distinct_values(data):
    values = list()
    
    s = data.shape
    for i in range(data.size):
        mid = np.unravel_index(i, s)
        v = data[mid]
        exists = False
        for j in range(len(values)):
            exists = exists or (v == values[j])
        if not exists:
            values.append(v)
    
    return values



mask = bisect(im)
plt.imshow(mask)

# %%
a = False
a = a or True
print(a)
# Out:
# True

# %%
def make_linked_function(**kwargs):
    functions = kwargs.pop('functions', [lambda x : x,])
    fct = lambda x : functions[0](x)
    for i in range(1, len(functions)):
        print(functions[i])
        fct = lambda x : functions[i](fct(x))
    return fct

fcts = list()
fcts.append(lambda x : 2*x)
fcts.append(lambda x : np.sqrt(x))
#fcts.append(lambda x : x+5)

combined_fct = make_linked_function(functions=fcts)
print(combined_fct(12.5))
# Out:
# <function <lambda> at 0x7f02848de9d8>
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-56-25932409f9c3> in <module>()
#      13
#      14 combined_fct = make_linked_function(functions=fcts)
# ---> 15 print(combined_fct(12.5))
#
# <ipython-input-56-25932409f9c3> in <lambda>(x)
#       4     for i in range(1, len(functions)):
#       5         print(functions[i])
# ----> 6         fct = lambda x : functions[i](fct(x))
#       7     return fct
#       8
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-56-25932409f9c3> in <lambda>(x)
#       4     for i in range(1, len(functions)):
#       5         print(functions[i])
# ----> 6         fct = lambda x : functions[i](fct(x))
#       7     return fct
#       8
#
# RecursionError: maximum recursion depth exceeded
