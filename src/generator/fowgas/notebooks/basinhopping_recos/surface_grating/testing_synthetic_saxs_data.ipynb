# %%
import aux
from synthetic_saxs import simulate_saxs_data
main = simulate_saxs_data.main

import numpy as np
from scipy import fftpack as fft
import pickle
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
fn      = 'test_result_123.pickle'

# %%
args    = ['main', '0.', '16', '8', '0.0', '0', '0', '256', '256', '2.7', '1e10', fn]
main(args)

# %%
with open(fn, 'rb') as file:
    savings = pickle.load(file)

# %%
ifft = fft.ifft2(fft.fftshift(savings.tailored_far_field))
dat  = np.log(np.abs(ifft))
plt.figure(figsize=(20,12))
plt.imshow(dat, **aux.iss)

# %%
dat = ifft[0, :]
plt.figure(figsize=(20,12))
plt.plot(dat)
# Out:
# /home/mz6084/.conda/envs/my_root/lib/python3.5/site-packages/numpy/core/numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
